# %%
dbutils.widgets.removeAll()
dbutils.widgets.text("capa", "", "capa")
dbutils.widgets.text("id", "", "id")

capa = dbutils.widgets.get("capa")
id = dbutils.widgets.get("id")

# %%
# %run /Workspace/Users/martin902503@gmail.com/retail_nova/nb_class

# %%
metadata = configuracion.configuracion_proceso(capa, id)
display(metadata)

# %%
from concurrent.futures import ThreadPoolExecutor

def process_table(i):
    tabla = i["nombre_archivo"]
    partitionBy = i["campo_particion"]
    id_proceso = i["id"]
    if i["flag_activo"] == True and i['flag_procesado'] == False:
        data = extraccion.consulta_csv(tabla)
        print(f"Info: Tabla {tabla} cargando .... \n")
        carga.carga_delta(id_proceso, data, tabla, capa, partitionBy=None)

rows = metadata.collect()
with ThreadPoolExecutor() as executor:
    executor.map(process_table, rows)

# %%
# %sql
select * from workspace.silver.inventario
