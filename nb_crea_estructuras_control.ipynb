# %%
# %sql

create or replace table workspace.configuration.configuracion_metadata
(
    id int,
    nombre_archivo string,
    path string,
    tipo_archivo string,
    capa string,
    campo_particion string,
    tabla_dependencia string,
    flag_procesado boolean,
    fecha_procesado timestamp,
    flag_activo boolean,
    fecha_configuracion timestamp,
    usuario string

)

# %%
# %sql
--insert into workspace.configuration.configuracion_metadata values (1,'inventario','/Workspace/Users/martin902503@gmail.com/retail_nova/data/','csv','bronze','','',false,null,true,current_timestamp(),'martin902503@gmail.com');
--insert into workspace.configuration.configuracion_metadata values (2,'tiendas','/Workspace/Users/martin902503@gmail.com/retail_nova/data/','csv','bronze','','',false,null,true,current_timestamp(),'martin902503@gmail.com');
--insert into workspace.configuration.configuracion_metadata values (3,'ventas_diarias_2m','/Workspace/Users/martin902503@gmail.com/retail_nova/data/','csv','bronze','','',false,null,true,current_timestamp(),'martin902503@gmail.com');

insert into workspace.configuration.configuracion_metadata values (4,'inventario','','delta','silver','','',false,null,true,current_timestamp(),'martin902503@gmail.com');
insert into workspace.configuration.configuracion_metadata values (5,'tiendas','','delta','silver','','',false,null,true,current_timestamp(),'martin902503@gmail.com');
insert into workspace.configuration.configuracion_metadata values (6,'ventas_diarias_2m','','delta','silver','','',false,null,true,current_timestamp(),'martin902503@gmail.com');

# %%
# %sql
select * from workspace.configuration.configuracion_metadata

# %%
# %sql
update workspace.configuration.configuracion_metadata set flag_procesado=false

# %%
# %sql
describe history workspace.bronze.ventas_diarias_2m
