# %%
# %sql

create or replace table workspace.configuration.configuracion_metadata
(
    id int,
    nombre_archivo string,
    path string,
    tipo_archivo string,
    capa string,
    campo_particion string,
    tabla_dependencia array<string>,
    atributos_llave string,
    flag_procesado boolean,
    fecha_procesado timestamp,
    flag_activo boolean,
    fecha_configuracion timestamp,
    usuario string

)

# %%
# %sql
delete from workspace.configuration.configuracion_metadata where capa='gold'

# %%
# %sql
--select * from workspace.silver.tiendas
--select * from workspace.silver.inventario
--select * from workspace.silver.ventas_diarias_2m
select * from workspace.silver.inventario_ventas_tiendas

# %%
# %sql
--insert into workspace.configuration.configuracion_metadata values (1,'inventario','/Workspace/Users/martin902503@gmail.com/retail_nova/data/','csv','bronze','',array(''),'',false,null,true,current_timestamp(),'martin902503@gmail.com');
--insert into workspace.configuration.configuracion_metadata values (2,'tiendas','/Workspace/Users/martin902503@gmail.com/retail_nova/data/','csv','bronze','',array(''),'',false,null,true,current_timestamp(),'martin902503@gmail.com');
--insert into workspace.configuration.configuracion_metadata values (3,'ventas_diarias_2m','/Workspace/Users/martin902503@gmail.com/retail_nova/data/','csv','bronze','',array(''),'',false,null,true,current_timestamp(),'martin902503@gmail.com');

--insert into workspace.configuration.configuracion_metadata values (4,'inventario','','delta','silver','',array('workspace.bronze.inventario'),'',false,null,true,current_timestamp(),'martin902503@gmail.com');
--insert into workspace.configuration.configuracion_metadata values (5,'tiendas','','delta','silver','',array('workspace.bronze.tiendas'),'',false,null,true,current_timestamp(),'martin902503@gmail.com');
--insert into workspace.configuration.configuracion_metadata values (6,'ventas_diarias_2m','','delta','silver','',array('workspace.bronze.ventas_diarias_2m'),'',false,null,true,current_timestamp(),'martin902503@gmail.com');
--insert into workspace.configuration.configuracion_metadata values (7,'inventario_ventas_tiendas','/Workspace/Users/martin902503@gmail.com/retail_nova/data_tranformacion_silver/nb_inventario_ventas_tiendas','delta','silver','',array('workspace.bronze.inventario','workspace.bronze.tiendas','workspace.bronze.ventas_diarias_2m'),'',false,null,true,current_timestamp(),'martin902503@gmail.com');

insert into workspace.configuration.configuracion_metadata values (8,'tiendas','','delta','gold','',array('workspace.silver.tiendas'),'id_tienda',false,null,true,current_timestamp(),'martin902503@gmail.com');
insert into workspace.configuration.configuracion_metadata values (9,'inventario','','delta','gold','',array('workspace.silver.inventario'),'id_producto',false,null,true,current_timestamp(),'martin902503@gmail.com');
insert into workspace.configuration.configuracion_metadata values (10,'ventas_diarias_2m','','delta','gold','',array('workspace.silver.ventas_diarias_2m'),'id_venta,fecha,id_tienda,id_producto',false,null,true,current_timestamp(),'martin902503@gmail.com');
insert into workspace.configuration.configuracion_metadata values (11,'inventario_ventas_tiendas','','delta','gold','',array('workspace.silver.inventario_ventas_tiendas'),'id_producto,fecha_actualizacion,fecha,id_tienda',false,null,true,current_timestamp(),'martin902503@gmail.com');

# %%
# %sql
---create or replace table workspace.configuration.configuracion_metadata_respaldo
--as

select * from workspace.configuration.configuracion_metadata --where capa='silver'
order by id

# %%
# %sql
update workspace.configuration.configuracion_metadata set flag_procesado=false --where capa = 'silver' --and nombre_archivo = 'inventario'

# %%
# %sql
describe history workspace.bronze.ventas_diarias_2m
