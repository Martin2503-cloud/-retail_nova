# %%
# %sql

create or replace table workspace.configuration.configuracion_archivos
(
    id int,
    nombre_archivo string,
    path string,
    tipo_archivo string,
    capa string,
    campo_particion string,
    flag_procesado boolean,
    fecha_procesado timestamp,
    flag_activo boolean,
    fecha_configuracion timestamp,
    usuario string

)

# %%
# %sql
select * from workspace.configuration.configuracion_archivos
